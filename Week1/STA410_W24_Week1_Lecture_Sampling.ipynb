# %% [markdown]
# <a name="cell-TOC-Sampling"></a>
#
# 0. [Syllabus](#cell-syllabus)
#
# 1. [Sampling](#cell-pythonlibs)
#
#     1. [Inverse CDF Sampling](#cell-Sampling-InverseCDF)
#     2. [Rejection Sampling](#cell-rejectionSampling)
#     3. [Importance Sampling](#cell-importanceSampling)

# %% [markdown]
# <a name="cell-pythonlibs"></a>
#
# # 1. [`numpy`](https://numpy.org/doc/stable/user/whatisnumpy.html) and  [`scipy.stats`](https://scipy.github.io/devdocs/tutorial/stats.html) ([Return to TOC](#cell-TOC-Sampling))
#
# ---
#
# - [`random`](https://docs.python.org/3/library/random.html): "Mersenne Twister" (MT19937)
# - [`np.random`](https://numpy.org/doc/stable/reference/random/#quick-start): "PCG64 has better statistical properties than MT19937"
#     - MT19937 nonetheless [still available](https://numpy.org/doc/stable/reference/random/bit_generators/mt19937.html)
#
# > [RNG](https://scipy.github.io/devdocs/tutorial/stats.html#random-number-generation) *Pseudorandomness* is
# > - based on "bit shuffling"
# > - pleasantly [comprehensive](https://docs.scipy.org/doc/scipy/reference/stats.html)
# > - not *true* ([random.org](random.org) style) *Randomness...*

# %% [markdown]
# <a name="cell-Sampling-InverseCDF"></a>
#
# # 1.A Inverse CDF Sampling ([Return to TOC](#cell-TOC-Sampling))
#
# <table>
# <tr>
# <td>
#
# ![](https://upload.wikimedia.org/wikipedia/commons/c/cc/Inverse_Transform_Sampling_Example.gif)
#
# </td>
# <td>
#
# ```python
# from scipy import stats
# import numpy as np
# import matplotlib.pyplot as plt
#
# support = np.linspace(0,10,100)
# n,X = 10000,stats.gamma(a=3)
#
# u = stats.uniform.rvs(size=n)
# x = X.ppf(u)
#
# plt.hist(X.ppf(u), density=True, bins=100)
# plt.plot(support, X.pdf(support))
# ```
#
# </td>
# </tr>
# </table>

# %% [markdown]
# # 1.A Inverse CDF Sampling

# %%
from scipy import stats; import numpy as np; import matplotlib.pyplot as plt
support = np.linspace(0,10,100); n,X = 10000,stats.gamma(a=3)
    
u = stats.uniform.rvs(size=n); x = X.ppf(u)
plt.figure(figsize=(12,5)); plt.hist(X.ppf(u), density=True, bins=100); plt.plot(support, X.pdf(support));

# %% [markdown]
# # 1.A Inverse CDF Sampling
#
#
# Good "Bit Shuffling" $U_i \sim U(0,1)$ *Pseudorandomness*...<br> is indistinguishable from *(actual true) Randomness*
# - ***Inverse CDF transformation*** of "Bit Shuffling" creates arbitrary $X_i \sim f_\theta(x)$ <br>
#   $\huge[$If the CDF of $X_i$ is $F_X(x)$, then $X_i \sim f_X(x) = \overset{\text{if it exists...}}{\frac{d}{dx}F_X(x)}$$\huge]$
#
# $$\large
# \begin{align*}
# F_X(x) = \overset{\int_{-\infty}^x f_\theta(\tilde x) d\tilde x}{Pr\left(X_i \leq x\right)} & = {} \overset{\text{If the inverse exists...}}{\overset{\text{Let }X_i = F_X^{-1}(U_i)}{Pr\left(F_X^{-1}(U_i) \leq x\right)}} \\
# & = {} Pr\left(U_i \leq \underset{\in [0,1]}{F_X(x)}\right) = F_X(x) \\
# &{} \Longrightarrow \quad X_i  \sim f_X(x)
# \end{align*}$$

# %% [markdown]
# <a name="cell-rejectionSampling"></a>
#
# # 1.B Rejection Sampling ([Return to TOC](#cell-TOC-Sampling))
#
# - ***Target distribution*** $f_{\theta} (x)$
# - ***Proposal distribution*** $\tilde f_{\tilde \theta} (\tilde x)$ [different from $f_{\theta}(x)$...]
#
# 0. Scaler $c$ such that $c \times \tilde f_{\tilde \theta} (x) > f_\theta(x)$ for all $x$ [then proceed to step 1; otherwise, fail]
#
# 1. Sample $\tilde x_j \sim \tilde f_{\tilde \theta}(\tilde X_j)$
# 2. Keep $x_i=\tilde x_j$ with probability $\frac{f_\theta(\tilde x_j)}{c \tilde f_\theta (\tilde x_j)}$; otherwise, discard [return to step 1 as desired]

# %% [markdown]
# # 1.B Rejection Sampling

# %%
from scipy import stats; import numpy as np; import matplotlib.pyplot as plt
# distribution of interest
X,support = stats.beta(2,2),np.linspace(0,1,100); plt.figure(figsize=(12,4)); plt.plot(support, X.pdf(support))
# and distribution tilde_p(tilde_x) such that c*tilde_p(x)>p(x) for all x
tilde_X,n = stats.uniform(),1000; tilde_x = X.rvs(size=n)
c,u = 1.6, stats.uniform.rvs(size=n) # auxiliary stuff to do rejection sampling
plt.plot(support, c*tilde_X.pdf(support)); plt.xlabel('X'); plt.ylabel('U')
plt.scatter(tilde_x, c*u, color=['b' if u<(X.pdf(x)/c*tilde_X.pdf(x)) else 'r' for x,u in zip(tilde_x,u)]);

# %% [markdown]
# # 1.B Rejection Sampling
#
# ***Rejection sampling*** chagnes the *univariate* sampling problem $X \sim f_\theta(x)$ into a *two-dimensional* problem $(\tilde X,U) \sim \tilde f(\tilde x,u) = \tilde f_{\tilde \theta}(\tilde x) \tilde f(u)$ that samples according to the desired probabilities
#
# \begin{align*}
# {Pr\left(\tilde X \leq x \;\big|\; U \leq \frac{f_\theta(\tilde X)}{c \tilde f_{\tilde \theta}(\tilde X)} \right)} & ={} Pr\left(\tilde X \leq x, U \leq \frac{f_\theta(\tilde X)}{c \tilde f_{\tilde \theta}(\tilde X)} \right) \Bigg/ Pr\left( U \leq \frac{f_\theta(\tilde X)}{c \tilde f_{\tilde \theta}(\tilde X)} \right)\\
# & ={} \int_{-\infty}^{x} \int_{0}^{\frac{f_\theta(\tilde x)}{c \tilde f_{\tilde \theta}(\tilde x)}} \tilde p_{\tilde \theta}(\tilde x) \;du\; d\tilde x  \Bigg/  \int_{-\infty}^{\infty} \int_{0}^{\frac{f_\theta(\tilde x)}{c \tilde f_{\tilde \theta}(\tilde x)}} \tilde f_{\tilde \theta}(\tilde x) \;du\; d\tilde x \\
# & ={} \int_{-\infty}^{x} {\frac{f_\theta(\tilde x)}{c }}  d\tilde x  \Bigg/  \int_{-\infty}^{\infty} {\frac{f_\theta(\tilde x)}{c }} d\tilde x  = \int_{-\infty}^{x} f_\theta(\tilde x) d\tilde x\\
# & ={} F_\theta( x)
# \end{align*}

# %% [markdown]
# <a name="cell-importanceSampling"></a>
#
# # 1.C Importance Sampling ([Return to TOC](#cell-TOC-Sampling))

# %%
# the importance sampling distribution tilde_p(tilde_x)
tilde_X,n = stats.uniform(),100000
tilde_x = tilde_X.rvs(size=n)
# the target distribution p(x)
X = stats.beta(2,2)
w = X.pdf(tilde_x)/tilde_X.pdf(tilde_x)
w = w/w.sum()
support = np.linspace(0,1,100)
plt.figure(figsize=(12,4)); plt.hist(tilde_x, density=True, bins=50, alpha=0.25); plt.plot(support, tilde_X.pdf(support)); plt.hist(tilde_x, weights=w, density=True, bins=50, alpha=0.5); plt.plot(support, X.pdf(support));

# %% [markdown]
# # 1.C Importance Sampling
#
# In providing weighted samples, ***importance sampling*** does not "sample" from a desired ***target distribution***; rather, it is representative of the ***target distribution*** in the sense that
#
# - ***unnormalized importance sampling*** provides ***unbiased estimation***
#
# \begin{align*}
# E_{X\sim f_\theta(x)}[g(X)] = \int g(x) f(x) dx &={} \int g(x) \frac{f_\theta(x)}{\tilde f_{\tilde \theta}(x)} \tilde f_{\tilde \theta}(x) dx\\
# \text{can be unbiasedly estimated as } &\color{white}={} \frac{1}{n}\sum_{i=1}^n g(x_i) \frac{f_\theta(x_i)}{\tilde f_{\tilde \theta}(x_i)} \quad \text{ for } \quad X_i \sim \tilde f_{\tilde \theta}(x_i)
# \end{align*}
#
#
# on the basis of a ***proposal distribution*** $\tilde f_{\tilde \theta} (\tilde x) \neq f_{\theta}(x)$ and ***importance weights*** $W_i^* = \frac{f(\tilde X_i)}{\tilde f(\tilde X_i)}$.
#
# - Rather than filtering ***proposal distribution*** samples (like ***rejection sampling***)<br>***importance sampling*** uses all samples but with ***importance weights***.

# %% [markdown]
# # 1.C Importance Sampling
#
# Rather than using the raw ***importance weights***, ***normalized importance weights*** can be used
#
# $$W_i^* = \frac{f(\tilde X_i)}{\tilde f(\tilde X_i)} \quad \text{ and } \quad W_i = \frac{ W_i^*}{\sum_{i=1}^n  W_i^*}$$
#
# although this will introduce some **bias** into the **estimation**.
#
# - However, it also means that the ***target distribution*** only needs to be known up to a proportionality constant $f_{\theta} (x) = cg(x)$ since this cancels upon ***normalization***
#
#
# $$\require{cancel}\color{gray}{W_i = \frac{ W_i^*}{\sum_{i=1}^n  W_i^*} = \frac{ f(\tilde X_i)/\tilde f(\tilde X_i)}{\sum_{i=1}^n  f(\tilde X_i)/\tilde f(\tilde X_i)} = \frac{ \cancel{c}g(\tilde X_i)/\tilde f(\tilde X_i)}{\sum_{i=1}^n  \cancel{c}g(\tilde X_i)/\tilde f(\tilde X_i)}}$$

# %% [markdown]
# # 1.C Importance Sampling
#
#
# > In Bayesian analysis a posterior can be evaluated proportionally as
# >
# > $$p(\theta | \mathbf{x}) \propto f(\mathbf{x}|\theta) p(\theta) \quad \text{(no  normalizing constant)}$$
# >
# > when computing the **marginal likelihood** $f(\textbf{x})$ is too expensive.
#
# **Importance sampling weights** are the normalized values of the likelihood if
#
# | Target Distribution | Proposal Distribution |
# |-|-|
# | posterior distribution $p(\theta \| \mathbf{x})$ | prior distribution $p(\theta)$|
#
#
#
# $$\require{cancel}
# W_i = \frac{f(\mathbf{x}|\theta_i)}{\sum_i f(\mathbf{x}|\theta_i)} \; \text{ since }
# W_i^* = \frac{p(\theta_i | \mathbf{x})}{p(\theta_i)} = \frac{f(\mathbf{x}|\theta_i) p(\theta_i)\overset{\text{normalization}}{/ \cancel{f(\mathbf{x})}}}{p(\theta_i)} = f(\mathbf{x}|\theta_i)
# $$
